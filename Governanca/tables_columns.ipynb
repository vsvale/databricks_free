# %%
# %sql
select * from system.information_schema.columns where table_catalog not in ("databricks_databricks_documentation_dataset","samples","system") and table_schema not in ("information_schema")

# %%
from_tables = ".".join(["*", "*", "*"])

# %%
from discoverx import DX

dx = DX()

# %%
from pyspark.sql.functions import col, lit

df = dx.from_tables(from_tables).with_sql("DESCRIBE EXTENDED {full_table_name}").apply().withColumn(
    "average_file_size_MB", col("sizeInBytes") / col("numFiles") / 1024 / 1024
).withColumn(
    "has_too_many_small_files",
    (col("average_file_size_MB") < small_file_max_size_MB) & (col("numFiles") > min_file_number),
).filter("table_catalog not in ('samples','system')")
