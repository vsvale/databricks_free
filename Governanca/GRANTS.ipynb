-- %% [markdown]
-- Must be owner or administrator
-- - PRIVILEGES - https://docs.databricks.com/aws/en/sql/language-manual/sql-ref-privileges#privilege-types

-- %%
%sql
GRANT ALL PRIVILEGES ON TABLE quality.default.columns TO `account users`;

-- %%
%sql
REVOKE MODIFY ON TABLE quality.default.columns FROM `account users`;

-- %%
%sql
SHOW GRANTS ON TABLE quality.default.columns;

-- %%
%sql
select * from system.information_schema.table_privileges where concat(table_catalog,".", table_schema,".", table_name) = 'quality.default.columns'
