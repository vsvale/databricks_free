# %% [markdown]
# https://apps-cookbook.dev/
# - Desenvolva localmente
# -   Use OAuth
# - Use pytest e playwrith para testes
# - Use DABs
# - CI pipeline para teste unitarios
# - CD para deploy
# - Use tokens On Behalf of para  autar em nome da identidade do usuario
