# %% [markdown]
# ---
# ### Use Cases
# - Question and answers
# - Content generation
# - Content personalization
# - Translation
# - Language style transfer
# - Story telling, creative writing
# - Code generation, auto-completion
# - Text summarization
# - Enterprise lnowledge management
# - Contract review
# - External chatbot
# ---

# %% [markdown]
# ![Screenshot 2025-09-21 171217.png](./Screenshot 2025-09-21 171217.png "Screenshot 2025-09-21 171217.png")
# ---

# %% [markdown]
# ![Screenshot 2025-09-21 172247.png](./Screenshot 2025-09-21 172247.png "Screenshot 2025-09-21 172247.png")

# %% [markdown]
# ---
# # Vector Search
# Serveless
# ---

# %% [markdown]
# ---
# ### Resources
# - Building AI Systems with Databricks - https://vimeo.com/1086028594
# ---
