# %% [markdown]
# # Genie Rooms Setup and Best Practice
#
# - *Self-service Q&A*: converse with your data in natural language
# - *Governed interaction* that adhere to your policies established in Unity Catalog
