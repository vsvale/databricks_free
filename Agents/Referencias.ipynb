# %% [markdown]
# [AI Agent Fundamentals](https://customer-academy.databricks.com/learn/courses/4482/ai-agent-fundamentals?hash=fb3c690cd5858385b7cd74958caf1898db621d68&generated_by=759152)

# %% [markdown]
# # System Prompt
# - Remember to think step by step before providing an answer
